# %%
from __future__ import print_function

import pandas as pd
import numpy as np
import pylab as pl

# %pylab inline

#establish the seed

#np.random.seed?

uniform_array = np.random.rand(10000)

pl.plot(uniform_array, '.')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
gaussian_array = np.random.randn(10000,10000)

pl.figure(figsize=(10,10))

pl.plot(gaussian_array[0],gaussian_array[1], '.')

# %%
#Figure out how the paramter degree of freedom relates to the mean

chisquare_array = np.random.chisquare(100, 2000)

pl.hist (chisquare_array)

mysizes = (2000 / np.array(range(1,101))

#Create a loop that runs a 100 times
chidist=[]
           
for i in range (0, len(mysize)):
    chidist.append(np.random.chisquare(100,mysize[i]))
# Out:
#   File "<ipython-input-48-2f702a84ab03>", line 10
#     chidist=[]
#           ^
# SyntaxError: invalid syntax
